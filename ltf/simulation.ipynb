# %%
import nbimporter
from bonding3 import AugmentedBondingCurve, TokenEngineering  # or do this --> from A import func1
import panel as pn

abc = AugmentedBondingCurve()

# %% [markdown]
# # Multi-Sigmoid Batch-Wise Bonding Curve

# %%
abc.view_abc()(abc)
# Out:
# Row
#     [0] Column(margin=5, name='AugmentedBondingCurve', width=300)
#         [0] StaticText(value='<b>AugmentedBondingCurve<...)
#         [1] FloatSlider(name='Zoom', start=0.01, step=0.01, value=0.05)
#         [2] FloatSlider(end=1050000.0, name='Current supply', start=1, step=1000, value=32907.019773862725)
#         [3] IntSlider(end=4, name='Reserve power', value=4)
#         [4] FloatSlider(end=17055.49778054646, name='Debt')
#     [1] Column
#         [0] ParamMethod(method)
#         [1] Row
#             [0] ParamMethod(method)
#             [1] ParamMethod(method)

# %%
CAD = 5000
abc.mint(CAD)
# Out:
# CAD: 5000 Price: 0.7609743222473347 Request: 6570.523937304261 Batch Available: 726.6138597709069
# CAD: 4447.065510525314 Price: 0.7679586156777498 Request: 5790.761923545354 Batch Available: 1051.05105005105
# CAD: 3639.901801121464 Price: 0.7751562387093617 Request: 4695.700839848641 Batch Available: 1051.05105005105
# CAD: 2825.1730224723665 Price: 0.7825751351315707 Request: 3610.0981179236974 Batch Available: 1051.05105005105
# CAD: 2002.6466049484868 Price: 0.7902235111950449 Request: 2534.2786902403222 Batch Available: 1051.05105005105
# CAD: 1172.0813537319073 Price: 0.7981098407257753 Request: 1468.57148467942 Batch Available: 1051.05105005105
# CAD: 333.22716758100495 Price: 0.8062428700006725 Request: 413.30866911198484 Batch Available: 1051.05105005105
# (6395.177779138141, 0.7818390938732955)

# %% [markdown]
# # Cashflow Operation - Token Engineering Services DAO

# %%
te = TokenEngineering()

# %%
te.view_te()(te)
# Out:
# Row
#     [0] Column(margin=5, name='TokenEngineering', width=300)
#         [0] StaticText(value='<b>TokenEngineering</b>')
#         [1] IntSlider(end=5000, name='Monthly salary', start=1500, step=500, value=5000)
#         [2] IntSlider(end=12, name='Number employees', start=3, value=7)
#         [3] IntSlider(end=24, name='Number months', start=3, value=24)
#         [4] IntSlider(end=10000, name='Monthly contract size', start=6000, step=50, value=7500)
#         [5] IntSlider(end=10, name='Number of initial c..., start=1, value=2)
#         [6] FloatSlider(end=3, name='New contracts per month', step=0.33, value=0.33)
#         [7] IntSlider(end=7000, name='Office expense', start=3000, step=50, value=7000)
#     [1] Column
#         [0] ParamMethod(method)
#         [1] ParamMethod(method)

# %% [markdown]
# Bonding curve bootstraps cashflow operations.
# Cashflow operations back growth on the curve.

# %% [markdown]
# Token rewards go to workers. Token holders vote on workers and earn yield.
